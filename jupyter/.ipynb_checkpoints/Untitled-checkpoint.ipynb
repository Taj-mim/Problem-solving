# %%
a=[1,2,3,45,6,7,1]
print(a)
print(max(a))
print(a)
a.reverse()
print(a)
print(a.count(1))
a.insert(3,19)
print(a)
print(sorted(a))
print(sorted(a,reverse=True)) 
b=[8,9,10,50]
print(a+b)
print(a*3)
print(sum(a),sum(b))
d=b.pop(1)
print(d)
# Out:
# [1, 2, 3, 45, 6, 7, 1]
# 45
# [1, 2, 3, 45, 6, 7, 1]
# [1, 7, 6, 45, 3, 2, 1]
# 2
# [1, 7, 6, 19, 45, 3, 2, 1]
# [1, 1, 2, 3, 6, 7, 19, 45]
# [45, 19, 7, 6, 3, 2, 1, 1]
# [1, 7, 6, 19, 45, 3, 2, 1, 8, 9, 10, 50]
# [1, 7, 6, 19, 45, 3, 2, 1, 1, 7, 6, 19, 45, 3, 2, 1, 1, 7, 6, 19, 45, 3, 2, 1]
# 84 77
# 9

# %%
f='Fatema taj'
l='tajmim'
d=print(' '.join([f,l]))

print((f+l)[-1])
print(l[::-1])
print(l[0:5:2])
b=(1,2,3,4,5,6)
print('My full name is {}.i am {} yrs old.'.format(f.title(),sum(b))
# Out:
#   Cell In[40], line 9
#     print('My full name is {}.i am {} yrs old.'.format(f.title(),sum(b))
#                                                                         ^
# _IncompleteInputError: incomplete input
